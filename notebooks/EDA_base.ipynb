# %% [markdown]
# # goodbooks-10k

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Ratings
# Ratings go from one to five. Both book IDs and user IDs are contiguous. For books, they are 1-10000, for users, 1-53424.

# %%
ratings = pd.read_csv( '../data/ratings.csv')
ratings
# Out:
#          user_id  book_id  rating
# 0              1      258       5
# 1              2     4081       4
# 2              2      260       5
# 3              2     9296       5
# 4              2     2318       3
# ...          ...      ...     ...
# 5976474    49925      510       5
# 5976475    49925      528       4
# 5976476    49925      722       4
# 5976477    49925      949       5
# 5976478    49925     1023       4
#
# [5976479 rows x 3 columns]

# %%
len(ratings.book_id.unique())
# Out:
# 10000

# %%
len(ratings.user_id.unique())
# Out:
# 53424

# %%
ratings.rating.hist(bins = 5)
# Out:
# <Axes: >

# %% [markdown]
# ### to_read
# Provides IDs of the books marked "to read" by each user, as user_id,book_id pairs, sorted by time. There are close to a million pairs

# %%
to_read = pd.read_csv('../data/to_read.csv')
to_read
# Out:
#         user_id  book_id
# 0             9        8
# 1            15      398
# 2            15      275
# 3            37     7173
# 4            34      380
# ...         ...      ...
# 912700    39374     1049
# 912701    10492     5180
# 912702    21879     4827
# 912703    21879     6642
# 912704    48192     7773
#
# [912705 rows x 2 columns]

# %%
len(to_read.book_id.unique())
# Out:
# 9986

# %%
len(to_read.user_id.unique())
# Out:
# 48871

# %% [markdown]
# ### Books
# Provies metadata for each book (goodreads IDs, authors, title, average rating, etc.). The metadata have been extracted from goodreads XML files, available in books_xml.

# %%
books = pd.read_csv('../data/books.csv')
books
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
books.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url'],
#       dtype='object')

# %%
books['image_url'][0] # does not work :(
# Out:
# 'https://images.gr-assets.com/books/1447303603m/2767052.jpg'

# %%
books.describe()
# Out:
#            book_id  goodreads_book_id  best_book_id       work_id  \
# count  10000.00000       1.000000e+04  1.000000e+04  1.000000e+04
# mean    5000.50000       5.264697e+06  5.471214e+06  8.646183e+06
# std     2886.89568       7.575462e+06  7.827330e+06  1.175106e+07
# min        1.00000       1.000000e+00  1.000000e+00  8.700000e+01
# 25%     2500.75000       4.627575e+04  4.791175e+04  1.008841e+06
# 50%     5000.50000       3.949655e+05  4.251235e+05  2.719524e+06
# 75%     7500.25000       9.382225e+06  9.636112e+06  1.451775e+07
# max    10000.00000       3.328864e+07  3.553423e+07  5.639960e+07
#
#         books_count        isbn13  original_publication_year  average_rating  \
# count  10000.000000  9.415000e+03                9979.000000    10000.000000
# mean      75.712700  9.755044e+12                1981.987674        4.002191
# std      170.470728  4.428619e+11                 152.576665        0.254427
# ...

# %%
reviews_per_book = ratings.groupby('book_id').book_id.apply(lambda x: len(x))
reviews_per_book.describe()
# Out:
# count    10000.000000
# mean       597.647900
# std       1267.289788
# min          8.000000
# 25%        155.000000
# 50%        248.000000
# 75%        503.000000
# max      22806.000000
# Name: book_id, dtype: float64
