# %%
import pandas as pd
import requests
import time
import os

# Простейшие настройки
INPUT_FILE = "books.csv"
OUTPUT_FILE = "books_result.csv"
COVERS_FOLDER = "covers"

# Создаем папку для картинок
os.makedirs(COVERS_FOLDER, exist_ok=True)

print("Начинаем поиск обложек...")

# Читаем файл
df = pd.read_csv(INPUT_FILE)
total = len(df)
print(f"Найдено книг: {total}")

# Список для результатов
all_results = []

# Обрабатываем каждую книгу по очереди
for i, row in df.iterrows():
    print(f"\nКнига {i+1}/{total}: ", end="")

    # Берем ISBN
    isbn = None
    for col in ['isbn13', 'isbn', 'ISBN']:
        if col in row and pd.notna(row[col]):
            isbn_str = str(row[col]).strip()
            # Простая очистка
            clean = ''.join(c for c in isbn_str if c.isdigit())
            if len(clean) >= 10:
                isbn = clean[:13]  # Берем максимум 13 цифр
                break

    if not isbn:
        print("нет ISBN")
        # Копируем строку как есть
        result = row.to_dict()
        result['cover_found'] = False
        result['cover_source'] = ''
        all_results.append(result)
        continue

    print(f"ISBN: {isbn}")

    # Копируем исходные данные
    result = row.to_dict()

    # Флаг что нашли
    found = False
    source = ''
    image_url = ''

    # Пробуем Open Library
    #time.sleep(1)  # Ждем секунду
    try:
        url = f"https://covers.openlibrary.org/b/isbn/{isbn}-L.jpg"
        resp = requests.get(url, timeout=10)
        if resp.status_code == 200 and 'image' in resp.headers.get('Content-Type', ''):
            # Сохраняем картинку
            filename = f"{isbn}_ol.jpg"
            path = os.path.join(COVERS_FOLDER, filename)
            with open(path, 'wb') as f:
                f.write(resp.content)

            found = True
            source = 'openlibrary'
            image_url = url
            print(f"  Найдено в Open Library")
    except:
        pass

    # Если не нашли, пробуем Google Books
    if not found:
        #time.sleep(1.5)  # Ждем еще
        try:
            url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"
            resp = requests.get(url, timeout=15)

            if resp.status_code == 200:
                data = resp.json()
                if 'items' in data and data['items']:
                    # Берем первую книгу
                    book = data['items'][0]
                    images = book.get('volumeInfo', {}).get('imageLinks', {})

                    # Пробуем разные размеры
                    for size in ['large', 'medium', 'thumbnail']:
                        if size in images:
                            img_url = images[size]
                            img_resp = requests.get(img_url, timeout=10)

                            if img_resp.status_code == 200:
                                # Сохраняем картинку
                                filename = f"{isbn}_gb.jpg"
                                path = os.path.join(COVERS_FOLDER, filename)
                                with open(path, 'wb') as f:
                                    f.write(img_resp.content)

                                found = True
                                source = 'google_books'
                                image_url = img_url
                                print(f"  Найдено в Google Books")
                                break
        except:
            pass

    # Записываем результат
    result['cover_found'] = found
    result['cover_source'] = source
    result['cover_url'] = image_url

    # Добавляем путь к файлу если нашли
    if found:
        filename = f"{isbn}_{source}.jpg"
        result['cover_path'] = os.path.join(COVERS_FOLDER, filename)
    else:
        result['cover_path'] = ''
        print(f"  Не найдено")

    all_results.append(result)

    # Показываем прогресс каждые 50 книг
    if (i + 1) % 50 == 0:
        found_count = sum(1 for r in all_results if r['cover_found'])
        print(f"\n=== Прогресс: {i+1}/{total}, найдено: {found_count} ===")

# Сохраняем все результаты
result_df = pd.DataFrame(all_results)
result_df.to_csv(OUTPUT_FILE, index=False, encoding='utf-8')

# Выводим итоги
found_total = result_df['cover_found'].sum()
print("\n" + "="*50)
print("ПОИСК ЗАВЕРШЕН!")
print(f"Всего книг: {total}")
print(f"Найдено обложек: {found_total} ({found_total/total*100:.1f}%)")
print(f"Результаты сохранены в: {OUTPUT_FILE}")
print("="*50)

# Показываем источники
if found_total > 0:
    sources = result_df[result_df['cover_source'] != '']['cover_source'].value_counts()
    print("\nИсточники обложек:")
    for src, count in sources.items():
        print(f"  {src}: {count}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   Найдено в Google Books
#
# Книга 8313/10000: ISBN: 9781598878740
#   Не найдено
#
# Книга 8314/10000: ISBN: 9780670016390
#   Найдено в Google Books
#
# Книга 8315/10000: нет ISBN
#
# Книга 8316/10000: ISBN: 9780140284130
#   Найдено в Google Books
#
# Книга 8317/10000: ISBN: 9780786901890
#   Найдено в Open Library
#
# Книга 8318/10000: ISBN: 9780446402410
#   Найдено в Google Books
#
# Книга 8319/10000: ISBN: 9780307272580
#   Найдено в Google Books
#
# Книга 8320/10000: ISBN: 9780345495170
#   Найдено в Google Books
#
# Книга 8321/10000: ISBN: 9781421506260
#   Не найдено
#
# Книга 8322/10000: ISBN: 9781401324440
#   Не найдено
#
# Книга 8323/10000: ISBN: 9780805080760
#   Найдено в Google Books
#
# Книга 8324/10000: ISBN: 9780425183240
#   Найдено в Google Books
#
# Книга 8325/10000: ISBN: 9781476791620
#   Найдено в Google Books
#
# Книга 8326/10000: ISBN: 9780062285510
#   Найдено в Google Books
#
# ...

# %%
df = pd.read_csv('books_result.csv')
df['cover_url'][1]
# Out:
# 'https://covers.openlibrary.org/b/isbn/9780439554930-L.jpg'

# %%
import polars as pl

df = pl.scan_csv("books_result.csv")
df.collect().write_parquet("books_result.parquet")
